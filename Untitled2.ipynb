# %% [markdown]
# <a href="https://colab.research.google.com/github/anyanwutakuchinwe/Deziree_Mod-J/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyxlsb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_excel("/content/drive/MyDrive/Comments analysis (version 1).xlsb")

# %%
data = pd.DataFrame(file)

# %%
# prompt: eda

# Display basic information about the DataFrame
print(data.info())

# Display summary statistics
print(data.describe())

# Check for missing values
print(data.isnull().sum())

# Explore unique values in categorical columns
for col in data.select_dtypes(include='object'):
  print(f"Unique values in {col}: {data[col].unique()}")

# Visualize distributions of numerical columns
for col in data.select_dtypes(include=np.number):
  plt.figure()
  sns.histplot(data[col])
  plt.title(f"Distribution of {col}")
  plt.show()

# Explore relationships between variables
sns.pairplot(data)
plt.show()

# Calculate correlations
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title("Correlation Matrix")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 2 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Unnamed: 0                                                      237 non-null    object
#  1   What one thing do you value most about working for BorgWarner?  234 non-null    object
# dtypes: object(2)
# memory usage: 3.8+ KB
# None
#                                    Unnamed: 0  \
# count                                     237
# unique                                      2
# top     Emissions, Thermal, and Turbo Systems
# freq                                      236
#
#        What one thing do you value most about working for BorgWarner?
# count                                                 234
# unique                                                227
# ...

# %%
# prompt: eda

# Display basic information about the DataFrame
print(data.info())

# Display summary statistics
print(data.describe())

# Check for missing values
print(data.isnull().sum())

# Explore unique values in categorical columns
for col in data.select_dtypes(include='object'):
  print(f"Unique values in {col}: {data[col].unique()}")

# Visualize distributions of numerical columns
for col in data.select_dtypes(include=np.number):
  plt.figure()
  sns.histplot(data[col])
  plt.title(f"Distribution of {col}")
  plt.show()

# Explore relationships between variables
sns.pairplot(data)
plt.show()

# Calculate correlations
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title("Correlation Matrix")
plt.show()
